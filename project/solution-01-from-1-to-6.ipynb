# %% [markdown]
# # Project Solution
#
# You have to work on the [Kiva](https://drive.google.com/file/d/1-tJtnIbo1Rt-F1XfoWGVkmBXiI-ciuRx/view) dataset. Some information on the datasets are on the [Kaggle](https://www.kaggle.com/gaborfodor/additional-kiva-snapshot) web page.

# %% [markdown]
# ## Basic tasks
#
# All groups and individual must do the following:
#
# `1.` Normalize the `loan_lenders` table. In the normalized table, each row must have one `loan_id` and one `lender`.

# %% [markdown]
# Firstly,necesery libraries are imported:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# After that, csv file is read and data frame with unnormalized data is created:

# %%
loans_lenders_un = pd.read_csv('../../Datasets/kiva/loans_lenders.csv')
#loans_lenders_un = loans_lenders_un.head() # Coment this in real situation, uncomment during development
loans_lenders_un
# Out:
#          loan_id                                            lenders
# 0         483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1         483738  muc888, nora3555, williammanashi, barbara5610,...
# 2         485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3         486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4         534428  muc888, niki3008, teresa9174, mike4896, david7...
# ...          ...                                                ...
# 1387427   678999  michael43411218, carol5987, gooddogg1, chris41...
# 1387428  1207353  rjhoward1986, jeffrey6870, trolltech4460, elys...
# 1387429  1206220  vicky7746, gooddogg1, fairspirit, craig9729960...
# 1387430  1206425  rich6705, sergiiy9766, angela7509, barbara5610...
# 1387431  1206486                              alan5175, amy38101311
#
# [1387432 rows x 2 columns]

# %% [markdown]
# Data frame with structured data will be created with help of intermediate object - list of pairs (loan_id, lender) packed in the dictionary:

# %%
lis = []
for index, row in loans_lenders_un.iterrows(): 
    ls = row['lenders'].split(',')
    for l in ls:
        lis.append({ 'loan_id' : row['loan_id'], 'lender': l.strip() })
loans_lender = pd.DataFrame(lis) 
loans_lender
# Out:
#           loan_id             lender
# 0          483693             muc888
# 1          483693            sam4326
# 2          483693        camaran3922
# 3          483693        lachheb1865
# 4          483693        rebecca3499
# ...           ...                ...
# 28293926  1206425  trogdorfamily7622
# 28293927  1206425          danny6470
# 28293928  1206425            don6118
# 28293929  1206486           alan5175
# 28293930  1206486        amy38101311
#
# [28293931 rows x 2 columns]

# %% [markdown]
# `2.` For each loan, add a column `duration` corresponding to the number of days between the disburse time and the planned expiration time. If any of those two dates is missing, also the duration must be missing.

# %% [markdown]
# Firstly, data frame should be loaded and structure of the data frame `loans` should be determined:

# %%
import pandas as pd
import numpy as np
loans = pd.read_csv('../../Datasets/kiva/loans.csv')
loans.columns
# Out:
# Index(['loan_id', 'loan_name', 'original_language', 'description',
#        'description_translated', 'funded_amount', 'loan_amount', 'status',
#        'activity_name', 'sector_name', 'loan_use', 'country_code',
#        'country_name', 'town_name', 'currency_policy',
#        'currency_exchange_coverage_rate', 'currency', 'partner_id',
#        'posted_time', 'planned_expiration_time', 'disburse_time',
#        'raised_time', 'lender_term', 'num_lenders_total',
#        'num_journal_entries', 'num_bulk_entries', 'tags', 'borrower_genders',
#        'borrower_pictured', 'repayment_interval', 'distribution_model'],
#       dtype='object')

# %% [markdown]
# After thar, several values from the begining of the data frame should be displayed:

# %%
loans_head = loans.head()
#loans = loans.head() # Coment this in real situation, uncomment during development
loans_head
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ...  \
# 0        125.0  funded  General Store       Retail  ...
# 1        400.0  funded  Used Clothing     Clothing  ...
# 2        400.0  funded  General Store       Retail  ...
# 3        625.0  funded        Farming  Agriculture  ...
# 4        425.0  funded        Farming  Agriculture  ...
#
#                      raised_time lender_term num_lenders_total  \
# 0  2014-01-15 04:48:22.000 +0000         7.0                 3
# 1  2014-02-25 06:42:06.000 +0000         8.0                11
# 2  2014-01-24 23:06:18.000 +0000        14.0                16
# 3  2014-01-22 05:29:28.000 +0000        14.0                21
# 4  2014-01-14 17:29:27.000 +0000         7.0                15
#
#   num_journal_entries num_bulk_entries  \
# 0                   2                1
# 1                   2                1
# 2                   2                1
# 3                   2                1
# 4                   2                1
#
#                                                 tags borrower_genders  \
# 0                                                NaN           female
# 1                                                NaN           female
# 2  #Woman Owned Biz, #Supporting Family, user_fav...           female
# 3                                      user_favorite           female
# 4           #Animals, #Eco-friendly, #Sustainable Ag             male
#
#    borrower_pictured repayment_interval distribution_model
# 0               true          irregular      field_partner
# 1               true            monthly      field_partner
# 2               true            monthly      field_partner
# 3               true            monthly      field_partner
# 4               true             bullet      field_partner
#
# [5 rows x 31 columns]

# %% [markdown]
# We are now mainly interested in columns 'planned_expiration_time', 'disburse_time':

# %%
loans_sel = loans[ ['loan_id', 'loan_name','planned_expiration_time', 'disburse_time'] ]
loans_sel
# Out:
#          loan_id           loan_name        planned_expiration_time  \
# 0         657307                Aivy  2014-02-14 03:30:06.000 +0000
# 1         657259      Idalia Marizza  2014-03-26 22:25:07.000 +0000
# 2         658010               Aasia  2014-02-15 21:10:05.000 +0000
# 3         659347             Gulmira  2014-02-21 03:10:02.000 +0000
# 4         656933             Ricky\t  2014-02-13 06:10:02.000 +0000
# ...          ...                 ...                            ...
# 1419602   988180                 NaN  2016-01-02 01:00:03.000 +0000
# 1419603   988213             Perlita  2016-01-02 16:40:07.000 +0000
# 1419604   989109  Okyeso Nyame Group  2016-01-03 22:20:04.000 +0000
# 1419605   989143            Exequila  2016-01-05 08:50:02.000 +0000
# 1419606   989240               Lydia  2016-01-03 20:50:06.000 +0000
#
#                          disburse_time
# 0        2013-12-22 08:00:00.000 +0000
# 1        2013-12-20 08:00:00.000 +0000
# 2        2014-01-09 08:00:00.000 +0000
# 3        2014-01-17 08:00:00.000 +0000
# 4        2013-12-17 08:00:00.000 +0000
# ...                                ...
# 1419602  2015-11-23 08:00:00.000 +0000
# 1419603  2015-11-24 08:00:00.000 +0000
# 1419604  2015-11-13 08:00:00.000 +0000
# 1419605  2015-11-03 08:00:00.000 +0000
# 1419606  2015-11-03 08:00:00.000 +0000
#
# [1419607 rows x 4 columns]

# %%
from datetime import datetime
loans['duration'] = None
for index, row in loans.iterrows(): 
    s2 = row['planned_expiration_time']
    s1 = row['disburse_time']
    if( pd.notna(s1) and pd.notna(s2) and s1 != '' and s2 != ''):
        d2 = datetime.strptime(s2, "%Y-%m-%d %H:%M:%S.%f %z")
        d1 = datetime.strptime(s1, "%Y-%m-%d %H:%M:%S.%f %z")
        loans.loc[index,'duration'] = (d2 - d1).days 
loans_sel = loans[ ['loan_id', 'loan_name','planned_expiration_time', 'disburse_time', 'duration'] ]
loans_sel
# Out:
#          loan_id           loan_name        planned_expiration_time  \
# 0         657307                Aivy  2014-02-14 03:30:06.000 +0000
# 1         657259      Idalia Marizza  2014-03-26 22:25:07.000 +0000
# 2         658010               Aasia  2014-02-15 21:10:05.000 +0000
# 3         659347             Gulmira  2014-02-21 03:10:02.000 +0000
# 4         656933             Ricky\t  2014-02-13 06:10:02.000 +0000
# ...          ...                 ...                            ...
# 1419602   988180                 NaN  2016-01-02 01:00:03.000 +0000
# 1419603   988213             Perlita  2016-01-02 16:40:07.000 +0000
# 1419604   989109  Okyeso Nyame Group  2016-01-03 22:20:04.000 +0000
# 1419605   989143            Exequila  2016-01-05 08:50:02.000 +0000
# 1419606   989240               Lydia  2016-01-03 20:50:06.000 +0000
#
#                          disburse_time duration
# 0        2013-12-22 08:00:00.000 +0000       53
# 1        2013-12-20 08:00:00.000 +0000       96
# 2        2014-01-09 08:00:00.000 +0000       37
# 3        2014-01-17 08:00:00.000 +0000       34
# 4        2013-12-17 08:00:00.000 +0000       57
# ...                                ...      ...
# 1419602  2015-11-23 08:00:00.000 +0000       39
# 1419603  2015-11-24 08:00:00.000 +0000       39
# 1419604  2015-11-13 08:00:00.000 +0000       51
# 1419605  2015-11-03 08:00:00.000 +0000       63
# 1419606  2015-11-03 08:00:00.000 +0000       61
#
# [1419607 rows x 5 columns]

# %% [markdown]
# `3.` Find the lenders that have funded at least twice.

# %% [markdown]
# Those are lenders that are duplicated in structured loan_leneders dataframe.

# %% [markdown]
# - One possible solution is based on calculation/counting using dicitionary object:

# %%
stat={}
for index, row in loans_lender.iterrows(): 
    lender = row['lender']
    stat[lender] = 1 + stat.get(lender, 0)
lenders_funded_2_more = []
for k in stat.keys():
    if( stat[k] >= 2):
        lenders_funded_2_more.append((k,stat[k]))
lenders_funded_2_more
# Out:
# [('muc888', 914),
#  ('sam4326', 680),
#  ('camaran3922', 48),
#  ('rebecca3499', 14995),
#  ('karlheinz4543', 1047),
#  ('jerrydb', 283),
#  ('paula8951', 110),
#  ('gmct', 128159),
#  ('amra9383', 10),
#  ('r3922', 9675),
#  ('brian9451', 270),
#  ('shree8053', 10036),
#  ('alan5513', 8822),
#  ('oisin3389', 3044),
#  ('helle8622', 142),
#  ('bo3186', 247),
#  ('ric8947', 80),
#  ('daniel98469874', 16119),
#  ('nick9464', 19),
#  ('deborah12671549', 680),
#  ('matthew9831', 106),
#  ('john6330', 1567),
#  ('john9479', 339),
#  ('mattiaslaven', 4735),
#  ('jonathan2867', 52),
#  ('jason3883', 994),
#  ('highgrovechurch', 28742),
#  ('maria3124', 25),
#  ('dino5102', 1425),
#  ('jonathan7946', 676),
#  ('ann8187', 367),
#  ('bryan2669', 201),
#  ('john88459657', 111),
#  ('eddyphil', 2397),
#  ('don9212', 24578),
#  ('carolineandcolin9686', 308),
#  ('bent8782', 209),
#  ('raph8817', 1287),
#  ('danielle2350', 263),
#  ('nora3555', 3),
#  ('williammanashi', 33),
#  ('barbara5610', 48925),
#  ('danhostetler', 150),
#  ('daniel1104', 1965),
#  ('amirali5409', 34661),
#  ('oceanwest', 2582),
#  ('greg69396003', 344),
#  ('trolltech4460', 150762),
#  ('thedragonflykeeper', 964),
#  ('patrick8466', 223),
#  ('priscilla3168', 56),
#  ('terrystl', 8266),
#  ('richardandsusan8352', 172),
#  ('sherri4341', 317),
#  ('gooddogg1', 177645),
#  ('danny6470', 5387),
#  ('jacqueline4838', 508),
#  ('diederik8163', 1062),
#  ('ryan54597608', 477),
#  ('james5068', 123),
#  ('rudi5955', 200),
#  ('daniel9859', 2410),
#  ('chandrakant6134', 198),
#  ('karyne5301', 114),
#  ('robert2280', 175),
#  ('darrellynne7000', 26),
#  ('bryan9912', 23),
#  ('sueandbob4088', 815),
#  ('pennie4480', 1056),
#  ('mike4896', 15033),
#  ('david7683', 6137),
#  ('dittes', 5885),
#  ('margaret7172', 149),
#  ('jessica1977', 35),
#  ('william7288', 106),
#  ('dennisg', 3208),
#  ('chrisbioteau', 491),
#  ('victor9593', 749),
#  ('peter3881', 385),
#  ('andrew8575', 6855),
#  ('stephen2848', 2186),
#  ('douglas8863', 60),
#  ('arthur1148', 80),
#  ('tristan7990', 39),
#  ('catherine7003', 50),
#  ('summer7416', 6),
#  ('jim8842', 2),
#  ('brett5260', 533),
#  ('roger2252', 100),
#  ('jolanda1942', 118),
#  ('anila7468', 23),
#  ('elizabeth31676552', 9),
#  ('john38425073', 2710),
#  ('marianne8717', 35),
#  ('lisette1963', 562),
#  ('motoharu1020', 1420),
#  ('elly3162', 177),
#  ('lena9976', 6286),
#  ('omkara', 22),
#  ('dougal1825', 1164),
#  ('jensdamsgaardvanar', 8182),
#  ('maeve9455', 8),
#  ('toni3909', 36),
#  ('eric4693', 1494),
#  ('martsrinandpete9620', 11132),
#  ('hans7879', 2041),
#  ('wonmilee', 104),
#  ('thomas93758238', 3402),
#  ('thomas1513', 712),
#  ('emofund', 11540),
#  ('phisquared', 534),
#  ('nealkapur', 1270),
#  ('vic5854', 2064),
#  ('christian8925', 571),
#  ('minerva9365', 14),
#  ('rebecca3038', 4624),
#  ('paul1853', 243),
#  ('zach7677', 51),
#  ('dana9865', 15484),
#  ('ankit3005', 64),
#  ('erich7889', 472),
#  ('judith5696', 20498),
#  ('klaus5005', 61),
#  ('john70242429', 493),
#  ('terry9343', 165),
#  ('karly7529', 5),
#  ('jodi8604', 33),
#  ('jitendra7163', 113),
#  ('leon2765', 302),
#  ('elizabeth8018', 12),
#  ('ramius65', 64),
#  ('kevin25138119', 11),
#  ('larissa7348', 33),
#  ('evan5101', 13),
#  ('vesa6130', 182),
#  ('mortens2943', 44),
#  ('corinne3582', 7),
#  ('zane9551', 10907),
#  ('christine3066', 173),
#  ('brett2942', 3),
#  ('karen1474', 190),
#  ('gw9898', 179),
#  ('maria1361', 18),
#  ('ashleyleah5650', 3270),
#  ('anne85489799', 343),
#  ('robert7675', 13),
#  ('harald8041', 172),
#  ('ken4292', 6),
#  ('alexander7609', 7),
#  ('rc4114', 521),
#  ('bernadette6835', 28),
#  ('jean2544', 435),
#  ('geko', 33),
#  ('lynn9800', 4),
#  ('brad4706', 132),
#  ('thomas9243', 172),
#  ('john56443992', 42),
#  ('karen84738084', 65),
#  ('steve2888', 231),
#  ('gayle9959', 1791),
#  ('melinda8816', 83),
#  ('karen1024', 8),
#  ('mbc1842', 14360),
#  ('herta6220', 380),
#  ('kaleddis', 43),
#  ('cruisecompete', 293),
#  ('ashna3311', 40),
#  ('wesley2313', 115),
#  ('juan6929', 183),
#  ('thomas7482', 3677),
#  ('dnak17', 600),
#  ('tom7497', 7390),
#  ('morten9659', 310),
#  ('sverker1303', 47),
#  ('kenanddoris2463', 237),
#  ('jennifer12256404', 57),
#  ('jude', 424),
#  ('marianne8308', 189),
#  ('aaronplaat', 123),
#  ('hollito', 671),
#  ('roger9399', 1481),
#  ('jenjh', 323),
#  ('bob6818', 104),
#  ('mmm2529', 120),
#  ('jultomten', 122),
#  ('aaron83574977', 22628),
#  ('minoa', 285),
#  ('donald1176', 1445),
#  ('henrik8047', 32),
#  ('david5193', 5434),
#  ('tippsnet', 82),
#  ('tiffanyww', 3),
#  ('tom2508', 16),
#  ('sachin9747', 42),
#  ('chris2963', 247),
#  ('srenchr1931', 6017),
#  ('eva5758', 3),
#  ('lukas3902', 200),
#  ('peter8627', 823),
#  ('katherine6420', 128),
#  ('russayres', 78),
#  ('joseph8886', 535),
#  ('jenny1824', 15),
#  ('jivan3702', 2528),
#  ('elizabeth6786', 98),
#  ('steve2304', 630),
#  ('yousaf9433', 899),
#  ('anne3221', 318),
#  ('pgodiwala', 239),
#  ('karen27277399', 115),
#  ('dale2883', 26),
#  ('theo8546', 512),
#  ('joannagiles7076', 870),
#  ('mark4564', 321),
#  ('nicki2616', 39),
#  ('FrequentMiler', 12397),
#  ('katie52857580', 8),
#  ('sara7523', 27),
#  ('brent8569', 78),
#  ('reetajaroope6400', 34),
#  ('anna3370', 279),
#  ('robert82472438', 80),
#  ('lloyd5595', 278),
#  ('peter3943', 45),
#  ('oliver5716', 83),
#  ('pureum8105', 1179),
#  ('lisa4011', 24),
#  ('ryan', 32),
#  ('davidberkowitz', 614),
#  ('Verdad', 2403),
#  ('evan7711', 5),
#  ('kate8576', 88),
#  ('cesarpwm11', 250),
#  ('tammy8086', 62),
#  ('gwyneth8834', 13),
#  ('john59229829', 1893),
#  ('olivia8246', 6),
#  ('tanya2648', 93),
#  ('frode1997', 247),
#  ('erik8516', 463),
#  ('stephane7818', 564),
#  ('jill1216', 10),
#  ('rory7597', 122),
#  ('julien3299', 25),
#  ('givingsomeback', 180),
#  ('mohammad5457', 111),
#  ('annemarie7077', 977),
#  ('stephen6879', 261),
#  ('dorothy2740', 60),
#  ('emma8443', 344),
#  ('sbastien6463', 52),
#  ('frederic9655', 50),
#  ('bill7550', 495),
#  ('martin6086', 1496),
#  ('brian1080', 26),
#  ('kathleen2227', 43),
#  ('robert5226', 192),
#  ('marjo1748', 1861),
#  ('clive5910', 16995),
#  ('steven3253', 10009),
#  ('brooke4972', 93),
#  ('tuire8253', 2),
#  ('cakeordeath8064', 399),
#  ('kevin7809', 593),
#  ('popness', 16),
#  ('maarten6927', 78),
#  ('wynne1047', 49),
#  ('laura4759', 996),
#  ('jennifer2139', 102),
#  ('daniel4451', 36),
#  ('cmak', 77),
#  ('drzero', 25),
#  ('rferons', 58),
#  ('joehoyle', 285),
#  ('lucy5005', 63),
#  ('liselotte2813', 116),
#  ('krauspartner', 4971),
#  ('william8070', 275),
#  ('al1898', 184),
#  ('hook', 462),
#  ('courtney8657', 112),
#  ('victor3619', 17),
#  ('sean4105', 35),
#  ('afroze4263', 800),
#  ('kaat7628', 113),
#  ('lisa9330', 73),
#  ('veronique2380', 26),
#  ('james14984376', 18),
#  ('mohannad', 78),
#  ('dragan9652', 135),
#  ('alice8507', 238),
#  ('danae3046', 639),
#  ('david3320', 68),
#  ('dan1417', 260),
#  ('mary5466', 232),
#  ('karin9948', 227),
#  ('holly2320', 39),
#  ('david81653552', 79),
#  ('peter1098', 89),
#  ('katy9250', 83),
#  ('race6335', 8),
#  ('greg2855', 45),
#  ('william61459677', 24),
#  ('carlton2205', 16),
#  ('jamie3277', 30),
#  ('lynn3173', 24),
#  ('teresaandrick', 6053),
#  ('coryandjona1206', 38),
#  ('nancy37087482', 24),
#  ('indiamos', 47),
#  ('scott2473', 149),
#  ('9678', 82),
#  ('marilyn9210', 48),
#  ('paul7054', 430),
#  ('sarah5545', 109),
#  ('craig97299604', 22311),
#  ('maria7751', 1415),
#  ('murray6640', 39),
#  ('erin6040', 11),
#  ('annw9506', 142),
#  ('vasanthi', 1020),
#  ('sue3979', 817),
#  ('pierre5880', 99),
#  ('daleandcallie9707', 58),
#  ('lisa4456', 423),
#  ('sacham', 1914),
#  ('tlaurie', 195),
#  ('janmarie3474', 12),
#  ('marian7076', 18),
#  ('allwinjose8370', 42),
#  ('michele8616', 21),
#  ('lucy4898', 107),
#  ('michael68567474', 2),
#  ('ryanandjoanna6615', 139),
#  ('suresh6523', 538),
#  ('danlandrum', 213),
#  ('Oliver10303', 9856),
#  ('jennifer6373', 213),
#  ('sue7474', 306),
#  ('elsa2087', 826),
#  ('patrick1809', 76),
#  ('elizabeth6032', 59),
#  ('shauna6520', 42),
#  ('james1059', 93),
#  ('mark4231', 10),
#  ('erika7219', 71),
#  ('benjamin3549', 736),
#  ('jim2503', 314),
#  ('sarah4958', 21),
#  ('anneke9304', 24),
#  ('houseofprayer2259', 24),
#  ('rune8044', 117),
#  ('joseph2420', 152),
#  ('andreaandwouter6544', 3401),
#  ('anthony9138', 36),
#  ('harald2732', 38),
#  ('tony9074', 72),
#  ('lesley6172', 45),
#  ('kevinandmary6376', 130),
#  ('deepakgeetakevinronak', 2434),
#  ('khanh2725', 1393),
#  ('nikocaro1392', 21),
#  ('harman2779', 90),
#  ('michael81276976', 238),
#  ('klaus5809', 289),
#  ('lesley4647', 85),
#  ('pedro2429', 726),
#  ('nollaig5959', 301),
#  ('evie2916', 144),
#  ('jim5285', 3230),
#  ('metin8315', 202),
#  ('gerald7282', 21),
#  ('debbieandmark5399', 199),
#  ('derekh', 279),
#  ('karin9520', 645),
#  ('lee6515', 5484),
#  ('thomas7955', 754),
#  ('sandeepsingh2858', 3976),
#  ('sarahandadam5448', 62),
#  ('rinie4717', 55),
#  ('chuck2380', 1194),
#  ('stefanomiari', 53),
#  ('doug4093', 61),
#  ('toplistbestfictionbo5564', 3717),
#  ('gerlinde6463', 821),
#  ('naomi67885443', 35),
#  ('mikemaria7249', 45),
#  ('tobias5075', 314),
#  ('tanmay', 489),
#  ('susan5953', 21),
#  ('douglas8995', 1269),
#  ('jeanne53233964', 1890),
#  ('jellodiva', 177),
#  ('judy3495', 7852),
#  ('denise7392', 753),
#  ('amornwan4232', 447),
#  ('terry52663587', 40),
#  ('cassie8926', 7),
#  ('wouterandfany', 291),
#  ('john9570', 19),
#  ('natasha7298', 7),
#  ('juergen5908', 412),
#  ('stacy1379', 41),
#  ('praveenrajasekar', 310),
#  ('patrickruetter', 121),
#  ('jane3454', 50),
#  ('christopher7476', 45),
#  ('nora6823', 19),
#  ('sarah1211', 167),
#  ('ryan1096', 19),
#  ('jcagomes', 197),
#  ('suzanne8918', 9),
#  ('kerry4093', 1415),
#  ('dave6914', 117),
#  ('gsk', 275),
#  ('harry9324', 158),
#  ('eileenandvictor8943', 115),
#  ('joan6711', 1292),
#  ('francine1535', 26),
#  ('craig1296', 38),
#  ('mac9412', 23),
#  ('eric8583', 91),
#  ('salandrob6186', 197),
#  ('caseyl', 144),
#  ('joannaandmike4344', 211),
#  ('norvan3688', 160),
#  ('john1288', 79),
#  ('neil6273', 111),
#  ('Leah6742', 160),
#  ('michaelandmelinda9592', 465),
#  ('karen2944', 51),
#  ('zach9722', 62),
#  ('jordan7519', 70),
#  ('thewalker9311', 20),
#  ('robert6772', 102),
#  ('sarahkathryn', 160),
#  ('karon4417', 38),
#  ('doug5185', 1818),
#  ('ronald8745', 12644),
#  ('charles6358', 202),
#  ('laura3959', 5),
#  ('kara1501', 9),
#  ('joan60553118', 38),
#  ('jessica4connections', 13),
#  ('shailesh', 405),
#  ('mingus8729', 223),
#  ('christian3503', 97),
#  ('nomax', 30),
#  ('frode', 141),
#  ('victorial2870', 111),
#  ('stephen5987', 249),
#  ('paul23765609', 2225),
#  ('paul6428', 201),
#  ('erin6824', 88),
#  ('jacob9653', 159),
#  ('william2639', 99),
#  ('elliot3732', 151),
#  ('connie4751', 143),
#  ('elena6794', 393),
#  ('carmen7376', 655),
#  ('laura1179', 121),
#  ('heather1546', 7192),
#  ('phillip7727', 1049),
#  ('marc1631', 788),
#  ('kris1903', 78),
#  ('angus2640', 1619),
#  ('jamesandshell2373', 250),
#  ('tamarab', 345),
#  ('mark2704', 7224),
#  ('indraneel7687', 234),
#  ('nancy7311', 1689),
#  ('shannonandpatti7539', 28),
#  ('george8634', 395),
#  ('frost', 76),
#  ('matthieu6433', 46),
#  ('matthew3047', 41),
#  ('janandmaggie7749', 584),
#  ('patricia1648', 62),
#  ('lidia1788', 165),
#  ('eunice7763', 58),
#  ('donald5571', 117),
#  ('richard7719', 522),
#  ('pamela5886', 12),
#  ('mike1401', 3177),
#  ('scott9873', 277),
#  ('brenda5160', 5),
#  ('michael21418121', 1004),
#  ('annette8725', 230),
#  ('regyjohn', 17),
#  ('rick8888', 1914),
#  ('craig7834', 186),
#  ('ben9420', 406),
#  ('morgan7663', 9),
#  ('susanne5176', 21),
#  ('hosewinckel7660', 100),
#  ('gao', 1219),
#  ('ed5743', 400),
#  ('amy7726', 80),
#  ('Ravi9208', 473),
#  ('albert8248', 333),
#  ('anne8157', 67),
#  ('adamcordle', 29),
#  ('lori9430', 16),
#  ('christopher5171', 119),
#  ('kamila1320', 111),
#  ('steve4890', 125),
#  ('donandkathy6425', 7065),
#  ('peter5514', 9),
#  ('tony7571', 225),
#  ('paulandrobyn5292', 26),
#  ('jennifer9341', 430),
#  ('kirkland', 2524),
#  ('stanhope8974', 117),
#  ('iole2405', 44),
#  ('arnaud4525', 247),
#  ('steven5197', 48),
#  ('nigel4691', 4202),
#  ('lpgiraldez', 140),
#  ('mihai3611', 5),
#  ('marcziesmer', 671),
#  ('robenlinda2270', 49),
#  ('vana5220', 1676),
#  ('lionel1946', 188),
#  ('david66129435', 1302),
#  ('sam8974', 164),
#  ('sijanrai', 65),
#  ('mike7912', 414),
#  ('delbert3382', 427),
#  ('jillian1643', 17439),
#  ('gregandclare1849', 1083),
#  ('tom7014', 651),
#  ('tomandjune3533', 1396),
#  ('JY1024', 13808),
#  ('charlie1085', 901),
#  ('julian8731', 33619),
#  ('detlef', 68),
#  ('anne9845', 850),
#  ('mike1219', 79),
#  ('john8871', 189),
#  ('david61297495', 2784),
#  ('divingdoc36', 11997),
#  ('pat5984', 177),
#  ('giovannicataldi4083', 9099),
#  ('pierre5663', 100),
#  ('diane3510', 142),
#  ('burger', 352),
#  ('victor3258', 2443),
#  ('thomas3234', 25),
#  ('szucheng2565', 32412),
#  ('ricardo7052', 30),
#  ('jack9289', 171),
#  ('richard4874', 465),
#  ('jessieinez', 76),
#  ('andyangie8000', 71),
#  ('maryana3992', 54),
#  ('idun4242', 143),
#  ('steve7920', 11),
#  ('willychu', 200),
#  ('irmark', 931),
#  ('martinezfamilynm', 58),
#  ('nazaret7843', 7917),
#  ('brian87298920', 125),
#  ('fiona7583', 66),
#  ('alex7802', 139),
#  ('rhonda6343', 105),
#  ('john37481062', 16991),
#  ('susan5956', 304),
#  ('albert8514', 345),
#  ('john1879', 1357),
#  ('zoec', 354),
#  ('sidney4048', 96),
#  ('uncleed1619', 58),
#  ('trogdorfamily7622', 13804),
#  ('sarah2583', 453),
#  ('mark99806535', 85),
#  ('dale2183', 297),
#  ('michelleandkristian9819', 3637),
#  ('jonesfamily', 283),
#  ('stacey7032', 37),
#  ('jane8369', 574),
#  ('mark9645', 94),
#  ('sabine4826', 11),
#  ('frdric2486', 220),
#  ('susan9076', 273),
#  ('gunhild2366', 39),
#  ('matthew7154', 264),
#  ('daleanddave4907', 1209),
#  ('michael1246', 354),
#  ('dean2234', 147),
#  ('james5070', 112),
#  ('hamish8276', 1795),
#  ('iannace', 495),
#  ('anne9124', 3544),
#  ('avezziefamily', 251),
#  ('owassofumc3326', 27),
#  ('ellen4684', 10133),
#  ('lynn5507', 103),
#  ('francois6628', 240),
#  ('phill9950', 488),
#  ('ilona9961', 588),
#  ('dina6457', 4),
#  ('bumpycat', 180),
#  ('enwezor2644', 32),
#  ('cathianne8063', 448),
#  ('marcandr8568', 1015),
#  ('mishka8668', 1739),
#  ('avi9735', 268),
#  ('barbara2376', 61),
#  ('susan2633', 3624),
#  ('gianandreaeandrea', 228),
#  ('laurelz', 228),
#  ('vgopinath', 48),
#  ('jose3712', 698),
#  ('gene8177', 195),
#  ('skreened', 3862),
#  ('jeff2322', 24),
#  ('kevin6441', 1003),
#  ('bill8134', 141),
#  ('richard1132', 92),
#  ('robert1951', 828),
#  ('gomike', 671),
#  ('neak', 1179),
#  ('pedersmed4472', 3417),
#  ('michael48913780', 577),
#  ('patrick8201', 46),
#  ('kaspar4426', 77),
#  ('malte4719', 78),
#  ('sarah10669637', 4),
#  ('john56537153', 403),
#  ('weinberger', 767),
#  ('daniel5023', 219),
#  ('kristin2911', 26),
#  ('Darebakus7028', 353),
#  ('arica', 1259),
#  ('michael63426267', 182),
#  ('joshuachan', 554),
#  ('magdalena9892', 270),
#  ('harold5997', 2641),
#  ('michael3061', 59),
#  ('tage', 21),
#  ('hedymaigs', 40),
#  ('linde6700', 591),
#  ('nigel5030', 10728),
#  ('Gallifante', 451),
#  ('caryl7997', 212),
#  ('alberto5618', 135),
#  ('donald3162', 667),
#  ('bill9445', 1053),
#  ('rich6705', 9075),
#  ('charles6568', 2165),
#  ('bubbascafe', 14),
#  ('tracey8474', 268),
#  ('daniel1064', 41),
#  ('dennis4138', 829),
#  ('jarrod4964', 523),
#  ('karen6436', 741),
#  ('EGL', 4199),
#  ('nick8730', 3126),
#  ('heike1534', 59),
#  ('beverly', 1277),
#  ('ken7832', 457),
#  ('gerald5541', 81),
#  ('andyonkiva', 3425),
#  ('margaret1978', 487),
#  ('susan9216', 199),
#  ('goodshepherducc9050', 1357),
#  ('pryor2007', 2510),
#  ('brenda6332', 204),
#  ('mark8092', 109),
#  ('david3125', 482),
#  ('anne3351', 30),
#  ('wjp', 1677),
#  ('benedictsteele', 68),
#  ('kim3330', 132),
#  ('marsha7181', 61),
#  ('lasse8792', 1054),
#  ('stephen2764', 167),
#  ('nathan7801', 540),
#  ('pascalvanhecke', 949),
#  ('jasonlee', 97),
#  ('ted8755', 12),
#  ('wayne6139', 20),
#  ('sharon4463', 17),
#  ('howard7012', 20719),
#  ('anders4222', 1348),
#  ('charlie3879', 1048),
#  ('matt50679987', 443),
#  ('joan9289', 281),
#  ('michele4530', 230),
#  ('maphew', 42),
#  ('zim7148', 8048),
#  ('melissa7297', 24),
#  ('julie3027', 37),
#  ('brendan1249', 27),
#  ('antonio6568', 56),
#  ('creativeeconomy', 105),
#  ('james4890', 142),
#  ('xyz1373', 57),
#  ('caroline4851', 35),
#  ('mags6440', 50),
#  ('starsknight', 169),
#  ('joanna6771', 704),
#  ('dorien8995', 39),
#  ('natalie4612', 10),
#  ('peggy1370', 31),
#  ('luke8286', 454),
#  ('chalanx', 25),
#  ('jannis9788', 299),
#  ('prabodh5470', 6),
#  ('diane6096', 19),
#  ('leslie8320', 19),
#  ('carlo9232', 442),
#  ('bernhard1113', 69),
#  ('jennifer86293639', 5757),
#  ('rie6860', 153),
#  ('natoya4299', 23),
#  ('tracey9969', 15),
#  ('roman6673', 533),
#  ('laurie9583', 46),
#  ('chad1043', 66),
#  ('hisadafamily8666', 49),
#  ('lauraleong', 19),
#  ('jim7785', 103),
#  ('thomas3791', 7635),
#  ('julie8037', 4675),
#  ('maureenandbill7908', 124),
#  ('joel5645', 75),
#  ('leeann5973', 125),
#  ('derek9183', 374),
#  ('stephen7228', 173),
#  ('timothy6485', 411),
#  ('sandy5828', 94),
#  ('tim4819', 111),
#  ('stewartandjoanna6718', 51),
#  ('albertw', 75),
#  ('timothy7790', 396),
#  ('wendy9105', 488),
#  ('roxandal5758', 67),
#  ('heidi9127', 23),
#  ('sandy3893', 681),
#  ('25perday', 1069),
#  ('ali91125852', 33),
#  ('angela6286', 502),
#  ('natalie16922915', 65),
#  ('matthew64195818', 170),
#  ('brooke8026', 62),
#  ('paula3738', 73),
#  ('catherine8081', 206),
#  ('christy2688', 287),
#  ('lindsay3373', 9),
#  ('jasoninchicago', 131),
#  ('jenny2529', 12),
#  ('frank3452', 639),
#  ('raymond4538', 873),
#  ('rob6883', 34),
#  ('vasu6972', 2380),
#  ('molly3537', 161),
#  ('jonathanheather1555', 82),
#  ('andrew2954', 995),
#  ('erica7803', 31),
#  ('ultrasara', 282),
#  ('john36421277', 404),
#  ('mariliis4011', 86),
#  ('renee8611', 68),
#  ('leanne5754', 95),
#  ('tim4058', 376),
#  ('sudds', 230),
#  ('jo8468', 44),
#  ('adamscottprice', 744),
#  ('wilma6195', 124),
#  ('nate4569', 44),
#  ('carolyn8576', 140),
#  ('kelly31908638', 24),
#  ('brenda9272', 21),
#  ('mary3259', 88),
#  ('caroline5418', 126),
#  ('anush6731', 33),
#  ('mel7714', 162),
#  ('vladstan', 116),
#  ('leejohn8697', 19),
#  ('lynn5475', 181),
#  ('suthi', 128),
#  ('ajit3049', 79),
#  ('toby1460', 7),
#  ('dawn6170', 96),
#  ('beth1817', 150),
#  ('michael64749969', 433),
#  ('tfrab', 28),
#  ('christopher38035375', 5178),
#  ('lloydminsterrotarycl6639', 2331),
#  ('julie9582', 5),
#  ('lorenzo7127', 557),
#  ('jeanetteingrid9958', 605),
#  ('kimberly5146', 36),
#  ('shirley1905', 40371),
#  ('barbara5987', 94),
#  ('alexiosstefanos5966', 10),
#  ('lorea3139', 251),
#  ('sean3201', 102),
#  ('jeffreyandannegret9319', 217),
#  ('douglas3301', 213),
#  ('steve8782', 926),
#  ('marion2587', 102),
#  ('judy9116', 46),
#  ('shane8924', 76),
#  ('gord6319', 101),
#  ('john5744', 246),
#  ('marthaandrobert8020', 635),
#  ('karin8006', 97),
#  ('dennis9163', 28),
#  ('sustainableequity9628', 50),
#  ('karen8054', 26),
#  ('sandy3287', 1433),
#  ('cchan3330', 485),
#  ('ben95621346', 449),
#  ('andrew5018', 82),
#  ('yoram3554', 155),
#  ('phonse5983', 61),
#  ('david77732635', 156),
#  ('normandmichelle8811', 1405),
#  ('howard4754', 11713),
#  ('kevinandkevin5061', 37),
#  ('jimandmaggie', 162),
#  ('halli1215', 27),
#  ('kate8166', 91),
#  ('gustavocpimenta', 26),
#  ('joann9259', 186),
#  ('william1104', 141),
#  ('peeta5736', 50),
#  ('tracy9170', 346),
#  ('eric3465', 13),
#  ('diane5157', 23),
#  ('christina1088', 224),
#  ('john6732', 31),
#  ('debra7424', 39),
#  ('nelson3926', 9),
#  ('haitham', 48),
#  ('michael6150', 1206),
#  ('wendy4343', 137),
#  ('austin1984', 490),
#  ('jaclyn4676', 26),
#  ('louise1987', 278),
#  ('neilthanedar', 63),
#  ('wendy5056', 26),
#  ('kate4058', 3363),
#  ('cathy6947', 63),
#  ('tonyonkiva', 415),
#  ('casschristine5146', 236),
#  ('kate3357', 103),
#  ('vito8085', 738),
#  ('victoria2140', 16),
#  ('agnieszka6878', 350),
#  ('tom1199', 230),
#  ('joacim2931', 646),
#  ('bobbie5048', 28),
#  ('alison3893', 59),
#  ('porter9696', 7370),
#  ('rachelle9002', 51),
#  ('leslie4054', 95),
#  ('janr9603', 56),
#  ('michael66234053', 37),
#  ('janandjohn', 4149),
#  ('michelle7526', 140),
#  ('tanya5801', 292),
#  ('patricia7040', 159),
#  ('kris7164', 84),
#  ('lifeinamsterdam', 109),
#  ('stevenandrhondabill', 203),
#  ('meghan2393', 11),
#  ('gilberto7688', 250),
#  ('jonathan6863', 1343),
#  ('max1495', 68),
#  ('rebecca4187', 50),
#  ('athena6426', 8),
#  ('debs8578', 158),
#  ('suzi6265', 65),
#  ('claudia3062', 645),
#  ('linda4162', 63),
#  ('alexander1835', 174),
#  ('migs2670', 1079),
#  ('mary4373', 50),
#  ('tove4710', 232),
#  ('robert5348', 380),
#  ('jan92', 53),
#  ('mlanie1854', 6),
#  ('carla2983', 27),
#  ('joakim8782', 63),
#  ('arealrattlesnake', 20),
#  ('laura1416', 3),
#  ('dan66559622', 454),
#  ('cate4432', 41),
#  ('tedandalexann8840', 29),
#  ('david64376525', 498),
#  ('james80465004', 99),
#  ('amy7407', 10),
#  ('jorge5645', 474),
#  ('kyle9253', 104),
#  ('shaun3027', 99),
#  ('laura4210', 11),
#  ('krisan8949', 6),
#  ('kara5723', 8),
#  ('johan4746', 190),
#  ('zan4576', 85),
#  ('karen94096564', 1475),
#  ('becky4310', 9),
#  ('eric9311', 2325),
#  ('svuorela', 158),
#  ('patrick1624', 86),
#  ('melanie8694', 30),
#  ('mattias3342', 239),
#  ('federica3226', 99),
#  ('julie5398', 21),
#  ('tomsve', 401),
#  ('richard57583833', 14),
#  ('marc9650', 22),
#  ('dirk3138', 15),
#  ('kristen5008', 12),
#  ('barbara9916', 423),
#  ('elizabeth8027', 41),
#  ('chris46268725', 5),
#  ('sheri7214', 132),
#  ('amy3374', 57),
#  ('linda1271', 121),
#  ('tobias1865', 10),
#  ('glenwood3349', 6),
#  ('riana4549', 70),
#  ('jasmine3207', 89),
#  ('annanathan8608', 126),
#  ('susanandbill4911', 61),
#  ('jan8763', 1130),
#  ('richard9693', 16),
#  ('cgull', 1491),
#  ('rachael8906', 528),
#  ('barbara5078', 209),
#  ('thomas8970', 141),
#  ('victoriusvixen', 41),
#  ('helen5675', 134),
#  ('darryl7606', 1481),
#  ('graham8286', 274),
#  ('l2253', 67),
#  ('andrea7380', 20),
#  ('boaz5464', 934),
#  ('leland6915', 1176),
#  ('neil000', 5882),
#  ('nadiamir', 137),
#  ('nathan4355', 208),
#  ('chad8960', 29),
#  ('angela5969', 401),
#  ('suzanne4305', 79),
#  ('june5576', 643),
#  ('pax5524', 34),
#  ('jan7030', 305),
#  ('zen7998', 278),
#  ('unitarianuniversali3384', 428),
#  ('rini', 20),
#  ('joan3580', 881),
#  ('elizabeth6283', 2275),
#  ('alicia9917', 59),
#  ('jon5113', 1253),
#  ('jeanie1305', 130),
#  ('jerryann8089', 27),
#  ('magaliefrance6900', 14),
#  ('helge5511', 208),
#  ('cyn5646', 191),
#  ('tina5592', 81),
#  ('bill8400', 110),
#  ('larrychris1406', 48),
#  ('thomasgraham', 289),
#  ('andy5122', 74),
#  ('laurin', 404),
#  ('frank8142', 561),
#  ('sarah30963630', 2),
#  ('michelle3865', 12),
#  ('premal', 635),
#  ('leslieinjapan', 947),
#  ('jonasb', 1126),
#  ('david7193', 673),
#  ('simon8263', 417),
#  ('sheelu', 43),
#  ('michael9752', 105),
#  ('elizabeth9621', 66),
#  ('massimo4704', 36),
#  ('virginia8803', 37),
#  ('ruth7034', 104),
#  ('yuri7211', 47),
#  ('fayeali', 245),
#  ('libby6618', 45),
#  ('joan6214', 62),
#  ('natasha5785', 7),
#  ('becauseyoucare', 255),
#  ('jon9748', 233),
#  ('peggy1697', 84),
#  ('maryanne3170', 232),
#  ('verodreams', 20),
#  ('kathleen8713', 22),
#  ('jan6672', 28),
#  ('rachel3298', 120),
#  ('sarah83079025', 863),
#  ('jodie4413', 103),
#  ('kathewelch', 510),
#  ...]

# %% [raw]
# - Alternative solution is based on panda functionality:

# %%
loans_lender_2_more = loans_lender[loans_lender.duplicated(['lender'])]
lenders_funded_2_more = list(set(loans_lender_2_more['lender']))
lenders_funded_2_more
# Out:
# ['crobin1313',
#  'salvador6678',
#  'domenico2152',
#  'dana8274',
#  'paul8821',
#  'erica4587',
#  'patricia4185',
#  'staffan9141',
#  'kristie8554',
#  'anna2573',
#  'queena7840',
#  'luc6184',
#  'emily1490',
#  'adrienne6434',
#  'sandra6009',
#  'kiran7697',
#  'denise2795',
#  'carolina9548',
#  'elaina3062',
#  'brian7172',
#  'jen2021',
#  'rolfz',
#  'akiko5445',
#  'rebecca7763',
#  'alexa6662',
#  'craig1040',
#  'sarah58888534',
#  'diane3480',
#  'neil6090',
#  'claudia5101',
#  'sophie3700',
#  'mayajk',
#  'maddiemii',
#  'franziska2715',
#  'dea4057',
#  'bruno1001',
#  'gary2135',
#  'yeo',
#  'johanna8821',
#  'jim79973404',
#  'james58372523',
#  'shaun8919',
#  'michael96315668',
#  'noah7862',
#  'elisabeth4705',
#  'jana9106',
#  'soumya8889',
#  'martha92445468',
#  'fred9624',
#  'fredrik4493',
#  'laura7000',
#  'nira1920',
#  'elyse6334',
#  'emily9169',
#  'alejandra8376',
#  'chris5067',
#  'michele9148',
#  'abby19618027',
#  'davidandbeverly5324',
#  'ryan41641240',
#  'keith4205',
#  'melissa3097',
#  'renata2808',
#  'elizabeth5140',
#  'nancy46041774',
#  'fidel4069',
#  'zach8728',
#  'amy5135',
#  'sara2619',
#  'cj5005',
#  'chris5936',
#  'myles2667',
#  'thomas8655',
#  'chloeandsunny5910',
#  'samantha3438',
#  'meiling7609',
#  'jessica22174706',
#  'elizabeth36632454',
#  'tyler9260',
#  'tamar6675',
#  'bria9456',
#  'marc43976381',
#  'james80819413',
#  'jennifer3279',
#  'julia7047',
#  'echo4960',
#  'annie7686',
#  'ellie1542',
#  'katrina8314',
#  'sam5006',
#  'jen6025',
#  'thomas8050',
#  'angelica2849',
#  'brenda35185274',
#  'norah1549',
#  'liz5780',
#  'cj6574',
#  'izzy3012',
#  'nellie5934',
#  'emmatoronto',
#  'nathan1628',
#  'charles7118',
#  'leandro4938',
#  'john48693769',
#  'golov',
#  'heath4816',
#  'julie21071343',
#  'grzegorz1584',
#  'jeff9624',
#  'emily',
#  'anthony7766',
#  'carla2022',
#  'sarah2661',
#  'john64992069',
#  'puravi9376',
#  'jennifer5568',
#  'moz',
#  'themezzaninecat',
#  'bryan5327',
#  'barbara8867',
#  'ujin1003',
#  'ann7020',
#  'bxcdj7418',
#  'kathleen4217',
#  'kenedy5579',
#  'christine4683',
#  'tom1183',
#  'kim8857',
#  'matthieu1130',
#  'jen5012',
#  'lisa85595023',
#  'susan9619',
#  'william6427',
#  'michelle25775369',
#  'shannon9314',
#  'annamarie9508',
#  'shira7558',
#  'eve2177',
#  'sam84836490',
#  'howard8766',
#  'heather4646',
#  'marcomoreira',
#  'kati6820',
#  'larry6739',
#  'john8254',
#  'john32651716',
#  'michael16896289',
#  'vivikka6327',
#  'chelsea8406',
#  'scarlett6183',
#  'stephanie4690',
#  'susie4253',
#  'garrett8523',
#  'rachel7699',
#  'paula37569940',
#  'amanda1293',
#  'fawaz4357',
#  'alexandra34877390',
#  'samuel7963',
#  'brian7157',
#  'rdhale44',
#  'rickandterry8763',
#  'roxanne5848',
#  'ramona5672',
#  'kristin9484',
#  'alice7891',
#  'ulco7978',
#  'paul69207115',
#  'caio2249',
#  'kellyandalain4550',
#  'hans9011',
#  'sue6268',
#  'jim6244',
#  'jahaira4571',
#  'katherine3492',
#  'linda76723509',
#  'caroline6062',
#  'cara7165',
#  'tascha7206',
#  'kathleen2806',
#  'maxine6910',
#  'rebeca6179',
#  'gryphonboy',
#  'randy7172',
#  'GiveforAllah',
#  'warren9611',
#  'susan4090',
#  'bk1625',
#  'david47373534',
#  'roynaldleonardo2379',
#  'andrea3528',
#  'joachim9593',
#  'anne3958',
#  'marilyn4951',
#  'elisa4551',
#  'nagendra5915',
#  'elizabeth27975497',
#  'bethany9594',
#  'lucy4639',
#  'gillian1058',
#  'mike2226',
#  'nida7642',
#  'dorcas2148',
#  'jefferey6481',
#  'morgan9298',
#  'david24657412',
#  'dag7054',
#  'miahopia',
#  'christine7598',
#  'ianfoz',
#  'jaeger4141',
#  'torrey6401',
#  'ronan1912',
#  'sandra21367421',
#  'jamestomu',
#  'anita5146',
#  'delisa1705',
#  'karen4994',
#  'breda6548',
#  'shona6560',
#  'qurratann8617',
#  'tiffany5409',
#  'scott8173',
#  'nickandjen',
#  'tiago5820',
#  'dale6745',
#  'jake1545',
#  'evaterz1399',
#  'laurie7411',
#  'ryan1961',
#  'greg8375',
#  'chris5366',
#  'barry9773',
#  'melanie3762',
#  'susan1927',
#  'shannon3353',
#  'adam6630',
#  'kari4692',
#  'eugenelaura1411',
#  'kimberly5101',
#  'sydney4279',
#  'diane39858205',
#  'ruth6484',
#  'elizabeth54215712',
#  'mfmmyi1790',
#  'brett6062',
#  'mike60404634',
#  'claudia54634407',
#  'michelle6835',
#  'clara5947',
#  'navyatha5423',
#  'jennifer42716831',
#  'annemarie5404',
#  'josee3532',
#  'sheila9582',
#  'rolf5505',
#  'denny5708',
#  'perkylnponnistus2494',
#  'josevicente8033',
#  'rajesh1851',
#  'tiffany98888229',
#  'harmony3892',
#  'aaron7191',
#  'rachel604',
#  'jeff8309',
#  'janis5099',
#  'patrick1404',
#  'carolynn6875',
#  'charles2830',
#  'eve6624',
#  'adam60657',
#  'mads7426',
#  'michele4936',
#  'travis8452',
#  'fisherfamily2894',
#  'jennifer77559882',
#  'everettlynn2949',
#  'william8306',
#  'kevin7697',
#  'hannah5180',
#  'laura86406497',
#  'mark4288',
#  'annesofie2133',
#  'pat2516',
#  'julia9199',
#  'jordan8570',
#  'rainer5129',
#  'kirk3656',
#  'curt9623',
#  'eun8532',
#  'planetrelations',
#  'celia3130',
#  'wendy57506245',
#  'naveen4717',
#  'angeline6925',
#  'rutvik3378',
#  'sara5556',
#  'olivier5080',
#  'karen21629625',
#  'leda5189',
#  'rachel1691',
#  'ripoll8817',
#  'linda2429',
#  'lucie2895',
#  'peter2326',
#  'cort5045',
#  'judith7199',
#  'chris4051',
#  'will1912',
#  'yomara6042',
#  'christy50408225',
#  'dianem3711',
#  'jeremy3273',
#  'jennifer1515',
#  'joe8678',
#  'jenni6294',
#  'seema0',
#  'yousef1463',
#  'sally3454',
#  'hans7042',
#  'jack9904',
#  'kelly9921',
#  'lisa4388',
#  'mariella7401',
#  'emily6244',
#  'geoff3817',
#  'garyandmary',
#  'richard4360',
#  'sarah5063',
#  'lisa5577',
#  'jan5508',
#  'marcia3068',
#  'megan3124',
#  'gwendolyn7453',
#  'britney7249',
#  'tj1369',
#  'chantal9688',
#  'buzz2395',
#  'roxie6538',
#  'ben1474',
#  'johnpaul7472',
#  'lucinda7036',
#  'aymeric4702',
#  'lisa97683865',
#  'yana2178',
#  'yanny9832',
#  'aimee8565',
#  'gregory9285',
#  'jeff7915',
#  'frank5316',
#  'ali9296',
#  'victoria9038',
#  'alex8651',
#  'jana5931',
#  'erika5797',
#  'bobbie8043',
#  'tarah4864',
#  'fabrizio4704',
#  'robert3922',
#  'jakob7277',
#  'steve2496',
#  'linda34707712',
#  'vivian6956',
#  'ertug9260',
#  'tilly3666',
#  'lethamprimaryschoo2414',
#  'alex5151',
#  'mary9214',
#  'blake2383',
#  'jenny5820',
#  'kenneth3466',
#  'lizette1817',
#  'karen1140',
#  'akio1857',
#  'beverley7495',
#  'guillermo4439',
#  'sabine8470',
#  'david9896',
#  'alex1625',
#  'armen3906',
#  'mike3093',
#  'caroline5274',
#  'susanne4431',
#  'jacqueskenedi',
#  'tim7232',
#  'gina7607',
#  'alan4927',
#  'adil2159',
#  'john6832',
#  'pedro5483',
#  'carly9804',
#  'amika8556',
#  'clarence4656',
#  'rachel346',
#  'patrick5139',
#  'tjslater',
#  'wendy9982',
#  'andy9328',
#  'aleana4977',
#  'karen4647',
#  'tricia6278',
#  'rebekah9764',
#  'anna8070',
#  'kylee5843',
#  'jennifer6416',
#  'joseph2884',
#  'anneli3146',
#  'gran3753',
#  'kyle7993',
#  'luis8823',
#  'rishi2035',
#  'ren5079',
#  'markshelly3545',
#  'rachel44279734',
#  'dina6957',
#  'ken7804',
#  'ralph7740',
#  'laurence9915',
#  'zoe1081',
#  'carolina1431',
#  'elaine9783',
#  'edwardr',
#  'ics6766',
#  'rk3657',
#  'leslie2490',
#  'tj3215',
#  'kirsten5082',
#  'jan2920',
#  'lindsay6825',
#  'joey3301',
#  'nikolas6431',
#  'bruceandruthi7909',
#  'ella9338',
#  'papeleux1013',
#  'barbara7173',
#  'sonia1725',
#  'donny5602',
#  'wendy92206712',
#  'starfevre',
#  'cheridan2583',
#  'lucy3045',
#  'matthew60359884',
#  'rakhi',
#  'sandra6418',
#  'herb2389',
#  'tommy5474',
#  'adam30994215',
#  'mary62025149',
#  'angelika9851',
#  'wynne7618',
#  'frank6419',
#  'mats4577',
#  'rob7841',
#  'gianluigi6848',
#  'artur5029',
#  'jenn5113',
#  'rob3130',
#  'maria64185039',
#  'maidaohorton',
#  'bernard9625',
#  'patrick3045',
#  'lisa93209120',
#  'stanislav1994',
#  'pamela2576',
#  'venkat6880',
#  'anna4979',
#  'greg7158',
#  'simon6674',
#  'andrew30667846',
#  'mariafernanda9975',
#  'chris8799',
#  'zacharias5279',
#  'connie8669',
#  'dan6554',
#  'cindy6051',
#  'ginger1784',
#  'dina3256',
#  'essam4520',
#  'matt5707',
#  'kathryn1613',
#  'alen4089',
#  'elsie5030',
#  'lisa7645',
#  'lundskakbank2326',
#  'richard5938',
#  'renee4641',
#  'leny9296',
#  'gay5368',
#  'cerise',
#  'klaas7838',
#  'tee8539',
#  'cynthia1030',
#  'elise7280',
#  'carmela8191',
#  'fabrizio5684',
#  'peter3310',
#  'jonathan1035',
#  'asmita8077',
#  'ulrike7112',
#  'sarah72021577',
#  'nick8188',
#  'don6838',
#  'linda1997',
#  'iakonacollege',
#  'jennifer6995',
#  'tyler6655',
#  'heidi7415',
#  'albert32238717',
#  'nancy1338',
#  'hilda4823',
#  'lorie2570',
#  'rita9998',
#  'sandra5985',
#  'theresa4611',
#  'maryclare7438',
#  'erin69663364',
#  'christine6704',
#  'erin53666510',
#  'shawn7963',
#  'navin7249',
#  'michael72131138',
#  'kathleen75356552',
#  'justin3805',
#  'paul8752',
#  'shaleen6192',
#  'tom94592202',
#  'paul8473',
#  'jerry1581',
#  'michael48288965',
#  'emma6673',
#  'mary70285846',
#  'veronika2622',
#  'ni1517',
#  'luis8500',
#  'ruth25643405',
#  'ivan6886',
#  'marineia8530',
#  'cherith4541',
#  'kimberley4477',
#  'sara3141',
#  'isaac2228',
#  'mandarr',
#  'ken2453',
#  'irene6090',
#  'tia7063',
#  'maria4062',
#  'sallie8003',
#  'teresa5141',
#  'nancy82197082',
#  'chris68783008',
#  'rebecca5518',
#  'wendy2387',
#  'sandra1171',
#  'amy28901780',
#  'gabrielle1419',
#  'carl3626',
#  'rene9650',
#  'david1850',
#  'anne77135651',
#  'steve6968',
#  'anna3023',
#  'lily2316',
#  'ron4975',
#  'lesley6017',
#  'wiko3246',
#  'lisa9504',
#  'nicholas5507',
#  'stephanie40026947',
#  'sarah9118',
#  'brooke7102',
#  'tristan8417',
#  'jan6656',
#  'stuart2195',
#  'robert9159',
#  'lucia5757',
#  'marcus4947',
#  'bart2048',
#  'kim1770',
#  'melinda4878',
#  'thomas3347',
#  'scott75318533',
#  'charles4951',
#  'kennet9107',
#  'cindy2334',
#  'abryl7238',
#  'lindsey5406',
#  'james49909550',
#  'hgpublishing',
#  'freya3701',
#  'peggy5639',
#  'shyla2923',
#  'martha6109',
#  'jakewurst',
#  'rick2464',
#  'jean4991',
#  'carrie9325',
#  'lisa3932',
#  'ninawallace4289',
#  'whitney8708',
#  'lital1071',
#  'marlayna6408',
#  'mary1078',
#  'janet8090',
#  'julie3315',
#  'barbara61886732',
#  'itii1024',
#  'raitzo',
#  'davidtanner7893',
#  'don21794995',
#  'mjane7617',
#  'jose1790',
#  'kim1342',
#  'david52855254',
#  'liz4560',
#  'john3338',
#  'abhinav3950',
#  'yael4824',
#  'camille1715',
#  'joan3706',
#  'tara2840',
#  'loretta9113',
#  'mrembo09',
#  'seeds5211',
#  'laura2006',
#  'arifa5191',
#  'tom9851',
#  'nicole1294',
#  'laurar7358',
#  'bblockwood',
#  'mihir7976',
#  'brandguy',
#  'priscilla1872',
#  'heather23703284',
#  'audrey2029',
#  'bev1398',
#  'zhao6422',
#  'junior1556',
#  'laurie2082',
#  'mark44264501',
#  'jess5226',
#  'hussaina3019',
#  'christine23759588',
#  'trent2758',
#  'ifat3435',
#  'stephen4587',
#  'gary6063',
#  'eileen7228',
#  'diana52076439',
#  'judith2041',
#  'adrian7699',
#  'judith6735',
#  'madhsuthanan1512',
#  'ineluki',
#  'larisa4688',
#  'liz7840',
#  'audreyed5261',
#  'citizenscholar',
#  'keegan5197',
#  'anamaria8394',
#  'betsy9018',
#  'george8369',
#  'lars5346',
#  'maria67983529',
#  'grace2141',
#  'esther4415',
#  'darstin21',
#  'roshan9321',
#  'ralph5149',
#  'heather8278',
#  'rick7597',
#  'madeline8548',
#  'rashidmayes',
#  'maia8245',
#  'gary3606',
#  'toby5767',
#  'mary7922',
#  'patti1439',
#  'marc1649',
#  'angelo3514',
#  'timothy7908',
#  'jr1601',
#  'emily3311',
#  'leslie3427',
#  'robert28525027',
#  'bill4602',
#  'sarah5719',
#  'tara4965',
#  'senior5463',
#  'cynthia9815',
#  'david10139955',
#  'laurie1955',
#  'john34584348',
#  'roxana6617',
#  'robert7210',
#  'shiko5107',
#  'sam6483',
#  'anna5013',
#  'frances4302',
#  'martha11347387',
#  'kailey2271',
#  'alegandron',
#  'tatiana4612',
#  'fletcher1255',
#  'stephanie1000',
#  'clarisse9121',
#  'xavier7815',
#  'david94999407',
#  'kevin8039',
#  'thomas8440',
#  'vidya1483',
#  'heather4348',
#  'p8277',
#  'katy4633',
#  'johan7527',
#  'roger1859',
#  'mark2761',
#  'shannon63696061',
#  'elizabeth4522',
#  'didi9216',
#  'jennifer4439',
#  'bradbethandfam3288',
#  'jason3503',
#  'jamesandbanu1114',
#  'anna59023231',
#  'julie1845',
#  'mikeandnickie2893',
#  'vikas1658',
#  'sq6nti',
#  'chas7589',
#  'heather2435',
#  'leigh6614',
#  'dennis3667',
#  'melissa2530',
#  'david39558384',
#  'belinda8143',
#  'mohamed5080',
#  'jennifer1743',
#  'joanna9329',
#  'mike95146460',
#  'brian4894',
#  'rebecca11235922',
#  'denise8215',
#  'janice5057',
#  'pam1535',
#  'emily6501',
#  'jody5639',
#  'sarah69338805',
#  'gina6856',
#  'lucia4761',
#  'john8832',
#  'jennifer57604361',
#  'robert7650',
#  'amin2340',
#  'webb',
#  'john6804',
#  'pamela5332',
#  'navnish8947',
#  'alex87286073',
#  'craige8499',
#  'katy9354',
#  'mary86791381',
#  'donnamarie3604',
#  'julia6301',
#  'sam5554',
#  'melinda3540',
#  'john82536113',
#  'sean1451',
#  'logan4383',
#  'nikki2468',
#  'gareth8480',
#  'anders9531',
#  'betty41937484',
#  'hanna6242',
#  'lisa62471756',
#  'allie7452',
#  'matt7721',
#  'teknicolor',
#  'sherie1349',
#  'hilarylittle',
#  'clare5009',
#  'scott94212056',
#  'elizabeth22772567',
#  'karey5929',
#  'search4careercolleges',
#  'timo8787',
#  'mario5880',
#  'michael6775',
#  'ann33198476',
#  'linden3372',
#  'daniel95648141',
#  'jan314',
#  'johnnie7586',
#  'KivaCanada',
#  'david2290',
#  'katherine3821',
#  'nitin4818',
#  'maxine2670',
#  'ruthellison',
#  'sue7880',
#  'cynthia6479',
#  'carole2938',
#  'stefanie2385',
#  'greg6502',
#  'jeff1092',
#  'kathy2543',
#  'rachelle8673',
#  'lisa3644',
#  'beatrice4683',
#  'stephanie9813',
#  'pavel2737',
#  'koujiro5171',
#  'nanette5865',
#  'michael40121409',
#  'susanna5273',
#  'karen82422083',
#  'richard68207282',
#  'marcusthearchitect',
#  'felixculpa',
#  'tom5464',
#  'alison40171269',
#  'vincentk',
#  'katherine7200',
#  'jessica3131',
#  'yvonne9691',
#  'jeremymelloul',
#  'joan5109',
#  'ali6902',
#  'johann8891',
#  'joost9186',
#  'andrea5322',
#  'alirezabozorgmir',
#  'zerka6125',
#  'julene4300',
#  'joey2703',
#  'lawrence7682',
#  'siobhan5575',
#  'bruno9025',
#  'joey3091',
#  'amanda6023',
#  'ges5thgradeclassnvus5171',
#  'stephen8180',
#  'kiera9915',
#  'margaretandaliza6015',
#  'aleksander6661',
#  'cindy4445',
#  'ellis8901',
#  'pete8621',
#  'christal4181',
#  'patty1034',
#  'margaret8486',
#  'mike1056',
#  'alicia5471',
#  'doug5110',
#  'ronald3870',
#  'luis69491891',
#  'patricia3894',
#  'craiga9905',
#  'asia5589',
#  'robert3615',
#  'natasha8897',
#  'auteema4214',
#  'galen2240',
#  'becky8414',
#  'gary4861',
#  'andrew44673453',
#  'anne9474',
#  'jaime9781',
#  'hilary6209',
#  'james83179971',
#  'susan2217',
#  'brandi3149',
#  'riccardo1986',
#  'kathy6774',
#  'cwjakob',
#  'noe3863',
#  'julie23973274',
#  'mike8724',
#  'danielle47662548',
#  'travis7571',
#  'marie8178',
#  'alida7543',
#  'judy9309',
#  'hillary7749',
#  'jonathan7689',
#  'ulrike6869',
#  'nikolay3556',
#  'sonia6723',
#  'jonathan1259',
#  'sarah5713',
#  'wendy4215',
#  'loydar9512',
#  'jan2653',
#  'brenda8879',
#  'janet6075',
#  'enrico5024',
#  'laura0108',
#  'robert2860',
#  'shannon7805',
#  'adrianna8541',
#  'kim5147',
#  'linda7606',
#  'bebs6252',
#  'caroline3919',
#  'dennis18825089',
#  'toddandaimee4154',
#  'austin9915',
#  'carol1725',
#  'matilda5087',
#  'henriikka',
#  'lupe4249',
#  'aimee8191',
#  'ruth1736',
#  'jeff72193347',
#  'emily25598738',
#  'jared5635',
#  'recklessabandonbookc8190',
#  'takashi7828',
#  'tobias9449',
#  'douglas8761',
#  'elizabeth5323',
#  'jiri6111',
#  'jane17518792',
#  'lloyd2091',
#  'marika9771',
#  'eric7855',
#  'magerezagail9560',
#  'jasper5984',
#  'dmitri3714',
#  'ross9336',
#  'brian69131648',
#  'mike38143128',
#  'balaji7568',
#  'marion5989',
#  'catherine3232',
#  'harry9244',
#  'jonathan4245',
#  'nancy1199',
#  'margaret97921941',
#  'deepa3117',
#  'pim4823',
#  'daniel6344',
#  'joseph2714',
#  'contextsubtext',
#  'james9255',
#  'hamish4469',
#  'lorraine3476',
#  'caroline6312',
#  'kristina5762',
#  'tobias1573',
#  'dave5863',
#  'donald7540',
#  'zoe3733',
#  'billothewisp',
#  'mohammad6552',
#  'erick2726',
#  'sian2920',
#  'peter1638',
#  'bill8280',
#  'carl4472',
#  'meuso6606',
#  'susan87052431',
#  'charles6128',
#  'robert8727',
#  'eric9134',
#  'jay74262975',
#  'stephanie2953',
#  'angela16975214',
#  'ole5251',
#  'caroline1955',
#  'danieladrienne7930',
#  'linda2940',
#  'javier8409',
#  'midge9699',
#  'jason44331377',
#  'telli9115',
#  'darlene7725',
#  'rachel4378',
#  'tom8278',
#  'peter7789',
#  'christopher29189909',
#  'torsten5025',
#  'robert5349',
#  'yoshiko7244',
#  'emily9984',
#  'theresa6833',
#  'louisa6800',
#  'suriya9636',
#  'payitforward2572',
#  'rana5556',
#  'susan1305',
#  'neil8420',
#  'rolf9602',
#  'ken7149',
#  'cristina9949',
#  'morag3001',
#  'joanne7000',
#  'uttam7404',
#  'christine4263',
#  'scott3560',
#  'vicente6619',
#  ...]

# %% [markdown]
# `4.` For each country, compute how many loans have involved that country as borrowers.

# %% [markdown]
# - One solution is based on calculation/counting using dicitionary object:

# %%
stat={}
for index, row in loans.iterrows(): 
    cn = row['country_name']
    cc = row['country_code']
    stat[(cc,cn)] = 1 + stat.get((cc,cn), 0)
stat
# Out:
# {('PH', 'Philippines'): 285336,
#  ('HN', 'Honduras'): 15130,
#  ('PK', 'Pakistan'): 45120,
#  ('KG', 'Kyrgyzstan'): 11243,
#  ('SV', 'El Salvador'): 64037,
#  ('BI', 'Burundi'): 1727,
#  ('ML', 'Mali'): 13352,
#  ('MN', 'Mongolia'): 9659,
#  ('PE', 'Peru'): 86000,
#  ('GE', 'Georgia'): 6483,
#  ('AM', 'Armenia'): 13952,
#  ('GH', 'Ghana'): 22121,
#  ('TZ', 'Tanzania'): 16110,
#  ('KH', 'Cambodia'): 79701,
#  ('TG', 'Togo'): 17106,
#  ('GT', 'Guatemala'): 12864,
#  ('LB', 'Lebanon'): 20083,
#  ('PY', 'Paraguay'): 24787,
#  ('NI', 'Nicaragua'): 42519,
#  ('KE', 'Kenya'): 143699,
#  ('UG', 'Uganda'): 45882,
#  ('RW', 'Rwanda'): 16774,
#  ('MZ', 'Mozambique'): 7086,
#  ('AZ', 'Azerbaijan'): 10172,
#  ('IL', 'Israel'): 464,
#  ('TJ', 'Tajikistan'): 43942,
#  ('BO', 'Bolivia'): 25250,
#  ('MX', 'Mexico'): 19708,
#  ('ID', 'Indonesia'): 10699,
#  ('NG', 'Nigeria'): 20015,
#  ('EC', 'Ecuador'): 33471,
#  ('MG', 'Madagascar'): 4872,
#  ('VN', 'Vietnam'): 21839,
#  ('CO', 'Colombia'): 33675,
#  ('JO', 'Jordan'): 10161,
#  ('YE', 'Yemen'): 4206,
#  ('IN', 'India'): 15104,
#  ('CL', 'Chile'): 892,
#  ('AL', 'Albania'): 3075,
#  ('PS', 'Palestine'): 13422,
#  ('NP', 'Nepal'): 2215,
#  ('SL', 'Sierra Leone'): 15576,
#  ('US', 'United States'): 9180,
#  ('CD', 'The Democratic Republic of the Congo'): 5074,
#  ('CM', 'Cameroon'): 5085,
#  ('WS', 'Samoa'): 16435,
#  ('DO', 'Dominican Republic'): 4654,
#  ('BJ', 'Benin'): 5946,
#  ('LR', 'Liberia'): 11170,
#  ('SN', 'Senegal'): 12107,
#  ('LA', "Lao People's Democratic Republic"): 1758,
#  ('MM', 'Myanmar (Burma)'): 2724,
#  ('IQ', 'Iraq'): 3570,
#  ('ZW', 'Zimbabwe'): 5513,
#  ('TH', 'Thailand'): 247,
#  ('BF', 'Burkina Faso'): 3489,
#  ('TL', 'Timor-Leste'): 3816,
#  ('HT', 'Haiti'): 4765,
#  ('UA', 'Ukraine'): 4994,
#  ('CG', 'Congo'): 952,
#  ('XK', 'Kosovo'): 2178,
#  ('AF', 'Afghanistan'): 2337,
#  ('ZA', 'South Africa'): 633,
#  ('SS', 'South Sudan'): 5820,
#  ('CR', 'Costa Rica'): 4681,
#  ('TR', 'Turkey'): 2008,
#  ('EG', 'Egypt'): 2460,
#  ('ZM', 'Zambia'): 1277,
#  ('BZ', 'Belize'): 218,
#  ('MW', 'Malawi'): 1731,
#  ('SR', 'Suriname'): 292,
#  ('SO', 'Somalia'): 227,
#  ('SB', 'Solomon Islands'): 903,
#  ('MD', 'Moldova'): 732,
#  ('CN', 'China'): 134,
#  ('BR', 'Brazil'): 482,
#  ('LS', 'Lesotho'): 648,
#  ('BA', 'Bosnia and Herzegovina'): 608,
#  ('CI', "Cote D'Ivoire"): 283,
#  ('LK', 'Sri Lanka'): 264,
#  ('PA', 'Panama'): 196,
#  ('PR', 'Puerto Rico'): 80,
#  ('BG', 'Bulgaria'): 296,
#  (nan, 'Namibia'): 9,
#  ('GZ', 'Gaza'): 8,
#  ('TD', 'Chad'): 61,
#  ('VC', 'Saint Vincent and the Grenadines'): 16,
#  ('VI', 'Virgin Islands'): 2,
#  ('VU', 'Vanuatu'): 4,
#  ('GU', 'Guam'): 4,
#  ('PG', 'Papua New Guinea'): 1,
#  ('CA', 'Canada'): 1,
#  ('BW', 'Botswana'): 1,
#  ('BT', 'Bhutan'): 2,
#  ('MR', 'Mauritania'): 1,
#  ('UY', 'Uruguay'): 1}

# %% [markdown]
# - Another solution is based on panda grouping:

# %%
loans_count = loans.groupby(['country_code','country_name'])['loan_id'].count()
loans_count
# Out:
# country_code  country_name
# AF            Afghanistan                2337
# AL            Albania                    3075
# AM            Armenia                   13952
# AZ            Azerbaijan                10172
# BA            Bosnia and Herzegovina      608
#                                         ...
# XK            Kosovo                     2178
# YE            Yemen                      4206
# ZA            South Africa                633
# ZM            Zambia                     1277
# ZW            Zimbabwe                   5513
# Name: loan_id, Length: 95, dtype: int64

# %% [markdown]
# `5.` For each country, compute the overall amount of money borrowed.

# %% [markdown]
# - One solution is based on calculation/sum using dicitionary object:

# %%
stat={}
for index, row in loans.iterrows(): 
    cn = row['country_name']
    cc = row['country_code']
    stat[(cc,cn)] = stat.get((cc,cn), 0) + row['loan_amount']
stat
# Out:
# {('PH', 'Philippines'): 97984600.0,
#  ('HN', 'Honduras'): 11989325.0,
#  ('PK', 'Pakistan'): 24995850.0,
#  ('KG', 'Kyrgyzstan'): 14726900.0,
#  ('SV', 'El Salvador'): 41691550.0,
#  ('BI', 'Burundi'): 5233450.0,
#  ('ML', 'Mali'): 15504675.0,
#  ('MN', 'Mongolia'): 15348375.0,
#  ('PE', 'Peru'): 79437775.0,
#  ('GE', 'Georgia'): 9570425.0,
#  ('AM', 'Armenia'): 22950475.0,
#  ('GH', 'Ghana'): 15262725.0,
#  ('TZ', 'Tanzania'): 18720300.0,
#  ('KH', 'Cambodia'): 51613525.0,
#  ('TG', 'Togo'): 10022825.0,
#  ('GT', 'Guatemala'): 18718050.0,
#  ('LB', 'Lebanon'): 27397150.0,
#  ('PY', 'Paraguay'): 53964700.0,
#  ('NI', 'Nicaragua'): 30153225.0,
#  ('KE', 'Kenya'): 66735975.0,
#  ('UG', 'Uganda'): 38386500.0,
#  ('RW', 'Rwanda'): 29157325.0,
#  ('MZ', 'Mozambique'): 4181100.0,
#  ('AZ', 'Azerbaijan'): 14784625.0,
#  ('IL', 'Israel'): 1732725.0,
#  ('TJ', 'Tajikistan'): 39622125.0,
#  ('BO', 'Bolivia'): 44226725.0,
#  ('MX', 'Mexico'): 25106300.0,
#  ('ID', 'Indonesia'): 8104600.0,
#  ('NG', 'Nigeria'): 7751725.0,
#  ('EC', 'Ecuador'): 35519000.0,
#  ('MG', 'Madagascar'): 1539075.0,
#  ('VN', 'Vietnam'): 24681100.0,
#  ('CO', 'Colombia'): 23613975.0,
#  ('JO', 'Jordan'): 11007450.0,
#  ('YE', 'Yemen'): 3444000.0,
#  ('IN', 'India'): 8988200.0,
#  ('CL', 'Chile'): 2595925.0,
#  ('AL', 'Albania'): 4307350.0,
#  ('PS', 'Palestine'): 22316675.0,
#  ('NP', 'Nepal'): 756125.0,
#  ('SL', 'Sierra Leone'): 11967500.0,
#  ('US', 'United States'): 46352000.0,
#  ('CD', 'The Democratic Republic of the Congo'): 18813425.0,
#  ('CM', 'Cameroon'): 2250800.0,
#  ('WS', 'Samoa'): 12212175.0,
#  ('DO', 'Dominican Republic'): 9308000.0,
#  ('BJ', 'Benin'): 3865825.0,
#  ('LR', 'Liberia'): 3928775.0,
#  ('SN', 'Senegal'): 17952175.0,
#  ('LA', "Lao People's Democratic Republic"): 1284800.0,
#  ('MM', 'Myanmar (Burma)'): 4201550.0,
#  ('IQ', 'Iraq'): 9166125.0,
#  ('ZW', 'Zimbabwe'): 5851875.0,
#  ('TH', 'Thailand'): 608925.0,
#  ('BF', 'Burkina Faso'): 4085200.0,
#  ('TL', 'Timor-Leste'): 3482400.0,
#  ('HT', 'Haiti'): 4496150.0,
#  ('UA', 'Ukraine'): 7091800.0,
#  ('CG', 'Congo'): 2265350.0,
#  ('XK', 'Kosovo'): 3083025.0,
#  ('AF', 'Afghanistan'): 1967950.0,
#  ('ZA', 'South Africa'): 1006525.0,
#  ('SS', 'South Sudan'): 2418300.0,
#  ('CR', 'Costa Rica'): 5644350.0,
#  ('TR', 'Turkey'): 903925.0,
#  ('EG', 'Egypt'): 1415025.0,
#  ('ZM', 'Zambia'): 1978975.0,
#  ('BZ', 'Belize'): 150175.0,
#  ('MW', 'Malawi'): 2182675.0,
#  ('SR', 'Suriname'): 748925.0,
#  ('SO', 'Somalia'): 308725.0,
#  ('SB', 'Solomon Islands'): 815575.0,
#  ('MD', 'Moldova'): 1357300.0,
#  ('CN', 'China'): 380525.0,
#  ('BR', 'Brazil'): 1192325.0,
#  ('LS', 'Lesotho'): 516450.0,
#  ('BA', 'Bosnia and Herzegovina'): 477250.0,
#  ('CI', "Cote D'Ivoire"): 345300.0,
#  ('LK', 'Sri Lanka'): 74800.0,
#  ('PA', 'Panama'): 321275.0,
#  ('PR', 'Puerto Rico'): 441900.0,
#  ('BG', 'Bulgaria'): 375300.0,
#  (nan, 'Namibia'): 39525.0,
#  ('GZ', 'Gaza'): 5000.0,
#  ('TD', 'Chad'): 20075.0,
#  ('VC', 'Saint Vincent and the Grenadines'): 49225.0,
#  ('VI', 'Virgin Islands'): 10000.0,
#  ('VU', 'Vanuatu'): 9250.0,
#  ('GU', 'Guam'): 17300.0,
#  ('PG', 'Papua New Guinea'): 50000.0,
#  ('CA', 'Canada'): 50000.0,
#  ('BW', 'Botswana'): 8000.0,
#  ('BT', 'Bhutan'): 20000.0,
#  ('MR', 'Mauritania'): 15000.0,
#  ('UY', 'Uruguay'): 8000.0}

# %% [markdown]
# - Another solution is based on panda grouping:

# %%
loans_sum = loans.groupby(['country_code','country_name'])['loan_amount'].sum()
loans_sum
# Out:
# country_code  country_name
# AF            Afghanistan                1967950.0
# AL            Albania                    4307350.0
# AM            Armenia                   22950475.0
# AZ            Azerbaijan                14784625.0
# BA            Bosnia and Herzegovina      477250.0
#                                            ...
# XK            Kosovo                     3083025.0
# YE            Yemen                      3444000.0
# ZA            South Africa               1006525.0
# ZM            Zambia                     1978975.0
# ZW            Zimbabwe                   5851875.0
# Name: loan_amount, Length: 95, dtype: float64

# %% [markdown]
# `6.` Like the previous point, but expressed as a percentage of the overall amount lent.

# %% [markdown]
# - One solution is based on calculation using dicitionary object:

# %%
stat={}
total = 0
for index, row in loans.iterrows(): 
    cn = row['country_name']
    cc = row['country_code']
    stat[(cc,cn)] = stat.get((cc,cn), 0) + row['loan_amount']
    total += row['loan_amount']
for k in stat.keys():
    stat[k] = stat[k]/total*100
stat
# Out:
# {('PH', 'Philippines'): 8.293677540060738,
#  ('HN', 'Honduras'): 1.0148084032897895,
#  ('PK', 'Pakistan'): 2.1157153240379327,
#  ('KG', 'Kyrgyzstan'): 1.2465240432141427,
#  ('SV', 'El Salvador'): 3.528883843433756,
#  ('BI', 'Burundi'): 0.4429731480460284,
#  ('ML', 'Mali'): 1.3123569909296076,
#  ('MN', 'Mongolia'): 1.2991273426021002,
#  ('PE', 'Peru'): 6.723824869927503,
#  ('GE', 'Georgia'): 0.8100662642020867,
#  ('AM', 'Armenia'): 1.9425893358877362,
#  ('GH', 'Ghana'): 1.2918776984610187,
#  ('TZ', 'Tanzania'): 1.5845360562088229,
#  ('KH', 'Cambodia'): 4.368706236039779,
#  ('TG', 'Togo'): 0.8483586052344885,
#  ('GT', 'Guatemala'): 1.5843456102156248,
#  ('LB', 'Lebanon'): 2.3189677522455066,
#  ('PY', 'Paraguay'): 4.567715950732214,
#  ('NI', 'Nicaragua'): 2.552249281447268,
#  ('KE', 'Kenya'): 5.648710684858181,
#  ('UG', 'Uganda'): 3.249135607958205,
#  ('RW', 'Rwanda'): 2.4679536527245247,
#  ('MZ', 'Mozambique'): 0.35389944096059944,
#  ('AZ', 'Azerbaijan'): 1.2514100409729743,
#  ('IL', 'Israel'): 0.14666245936199915,
#  ('TJ', 'Tajikistan'): 3.3537221992229296,
#  ('BO', 'Bolivia'): 3.7434678082366286,
#  ('MX', 'Mexico'): 2.125064106237377,
#  ('ID', 'Indonesia'): 0.6859949317665864,
#  ('NG', 'Nigeria'): 0.656126651833322,
#  ('EC', 'Ecuador'): 3.0064227699599466,
#  ('MG', 'Madagascar'): 0.1302714075474001,
#  ('VN', 'Vietnam'): 2.0890740456560835,
#  ('CO', 'Colombia'): 1.9987497432153192,
#  ('JO', 'Jordan'): 0.9316998879246492,
#  ('YE', 'Yemen'): 0.2915093335888413,
#  ('IN', 'India'): 0.7607851893621439,
#  ('CL', 'Chile'): 0.2197260066192256,
#  ('AL', 'Albania'): 0.3645855772456143,
#  ('PS', 'Palestine'): 1.8889428156703703,
#  ('NP', 'Nepal'): 0.06400043404757917,
#  ('SL', 'Sierra Leone'): 1.012961077155766,
#  ('US', 'United States'): 3.923356745211955,
#  ('CD', 'The Democratic Republic of the Congo'): 1.5924184042606409,
#  ('CM', 'Cameroon'): 0.19051370732919978,
#  ('WS', 'Samoa'): 1.0336710208827842,
#  ('DO', 'Dominican Republic'): 0.7878539131953934,
#  ('BJ', 'Benin'): 0.32721372518033753,
#  ('LR', 'Liberia'): 0.33254198085670733,
#  ('SN', 'Senegal'): 1.5195199101975194,
#  ('LA', "Lao People's Democratic Republic"): 0.10874889424940283,
#  ('MM', 'Myanmar (Burma)'): 0.35563038343211273,
#  ('IQ', 'Iraq'): 0.7758452352909461,
#  ('ZW', 'Zimbabwe'): 0.4953182873098725,
#  ('TH', 'Thailand'): 0.051541033959229154,
#  ('BF', 'Burkina Faso'): 0.3457822095171703,
#  ('TL', 'Timor-Leste'): 0.2947596118727587,
#  ('HT', 'Haiti'): 0.38056611214154146,
#  ('UA', 'Ukraine'): 0.600268842028265,
#  ('CG', 'Congo'): 0.19174525808521536,
#  ('XK', 'Kosovo'): 0.26095544808006316,
#  ('AF', 'Afghanistan'): 0.16657252991758428,
#  ('ZA', 'South Africa'): 0.08519495702395717,
#  ('SS', 'South Sudan'): 0.20469135348951656,
#  ('CR', 'Costa Rica'): 0.4777528185372173,
#  ('TR', 'Turkey'): 0.07651061973411538,
#  ('EG', 'Egypt'): 0.11977148512240132,
#  ('ZM', 'Zambia'): 0.1675057152842559,
#  ('BZ', 'Belize'): 0.012711212012689967,
#  ('MW', 'Malawi'): 0.18474742586847395,
#  ('SR', 'Suriname'): 0.06339100686934465,
#  ('SO', 'Somalia'): 0.02613130633339577,
#  ('SB', 'Solomon Islands'): 0.06903244040119606,
#  ('MD', 'Moldova'): 0.11488548736356978,
#  ('CN', 'China'): 0.03220864958301215,
#  ('BR', 'Brazil'): 0.10092156392895331,
#  ('LS', 'Lesotho'): 0.04371370363877965,
#  ('BA', 'Bosnia and Herzegovina'): 0.040395711223947306,
#  ('CI', "Cote D'Ivoire"): 0.029227111756163444,
#  ('LK', 'Sri Lanka'): 0.006331271240547424,
#  ('PA', 'Panama'): 0.02719357176212398,
#  ('PR', 'Puerto Rico'): 0.03740359306414314,
#  ('BG', 'Bulgaria'): 0.03176639166547391,
#  (nan, 'Namibia'): 0.0033455012805165374,
#  ('GZ', 'Gaza'): 0.00042321331821841074,
#  ('TD', 'Chad'): 0.0016992014726469192,
#  ('VC', 'Saint Vincent and the Grenadines'): 0.0041665351178602535,
#  ('VI', 'Virgin Islands'): 0.0008464266364368215,
#  ('VU', 'Vanuatu'): 0.0007829446387040598,
#  ('GU', 'Guam'): 0.0014643180810357012,
#  ('PG', 'Papua New Guinea'): 0.004232133182184107,
#  ('CA', 'Canada'): 0.004232133182184107,
#  ('BW', 'Botswana'): 0.0006771413091494571,
#  ('BT', 'Bhutan'): 0.001692853272873643,
#  ('MR', 'Mauritania'): 0.0012696399546552322,
#  ('UY', 'Uruguay'): 0.0006771413091494571}

# %% [markdown]
# - Another solution is based on panda functions:

# %%
loans_total = loans['loan_amount'].sum()
loans_percent = loans.groupby(['country_code','country_name'])['loan_amount'].sum()/loans_total*100
loans_percent
# Out:
# country_code  country_name
# AF            Afghanistan               0.166573
# AL            Albania                   0.364586
# AM            Armenia                   1.942589
# AZ            Azerbaijan                1.251410
# BA            Bosnia and Herzegovina    0.040396
#                                           ...
# XK            Kosovo                    0.260955
# YE            Yemen                     0.291509
# ZA            South Africa              0.085195
# ZM            Zambia                    0.167506
# ZW            Zimbabwe                  0.495318
# Name: loan_amount, Length: 95, dtype: float64

# %% [markdown]
# `7.` Like the three previous points, but split for each year (with respect to `disburse time`).

# %% [markdown]
# `8.` For each lender, compute the overall amount of money lent. For each loan that has more than one lender, you must assume that all lenders contributed the same amount.

# %% [markdown]
# `9.` For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.

# %% [markdown]
# `10.` Which country has the highest ratio between the difference computed at the previous point and the population?

# %% [markdown]
# `11.` Which country has the highest ratio between the difference computed at point 9 and the population that is not below the poverty line?

# %% [markdown]
# `12.` For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD * 31 / (31+365+30) = 363.85 for 2016, 5000USD * 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.
